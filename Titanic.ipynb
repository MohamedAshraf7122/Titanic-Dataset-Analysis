# %%
import pandas as pd
import numpy as np

# The URL for the Titanic dataset
url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'

# Your code here
titanic_df=pd.read_csv(url)

# %%
titanic_df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
titanic_df.iloc[-5:]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
titanic_df.shape
# Out:
# (891, 12)

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
display(titanic_df.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# statistical summary for all categorical columns (object types).

# %%
titanic_df.value_counts()
# Out:
# PassengerId  Survived  Pclass  Name                                                 Sex     Age   SibSp  Parch  Ticket    Fare     Cabin        Embarked
# 2            1         1       Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0  1      0      PC 17599  71.2833  C85          C           1
# 4            1         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)         female  35.0  1      0      113803    53.1000  C123         S           1
# 7            0         1       McCarthy, Mr. Timothy J                              male    54.0  0      0      17463     51.8625  E46          S           1
# 11           1         3       Sandstrom, Miss. Marguerite Rut                      female  4.0   1      1      PP 9549   16.7000  G6           S           1
# 12           1         1       Bonnell, Miss. Elizabeth                             female  58.0  0      0      113783    26.5500  C103         S           1
# ...

# %% [markdown]
# unique values  in the 'Pclass' column?

# %%
titanic_df["Pclass"].nunique()
# Out:
# 3

# %% [markdown]
#  unique values in the 'Embarked' column?

# %%
titanic_df["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %% [markdown]
# How many passengers embarked from each port?

# %%
titanic_df["Embarked"].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %% [markdown]
# missing data.

# %%
titanic_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# the percentage of missing values for each column.

# %%
titanic_df.isnull().mean()*100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %% [markdown]
#  Passengers and features: 891 passengers ,12 features
#
#  Columns with most missing values: Embarked,Age,Cabin
#
#  Oldest passenger's age:80
#
#  Median fare: 14.454200
#
# 'SibSp' represents: number of siblings onbroad
#
# 'Parch' represents: number of parents or childs onbroad

# %% [markdown]
# The 'Age' column is important but has missing values. We will fill them using the median age.

# %%
median_age=titanic_df["Age"].median()

# %%
titanic_df["Age"].fillna(median_age,inplace=True)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_3976\3050158313.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic_df["Age"].fillna(median_age,inplace=True)

# %% [markdown]
# Verify that there are no more missing values in the 'Age' column.

# %%
titanic_df["Age"].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# The 'Embarked' column has a few missing values. We will fill them with the most common embarkation port (the mode).

# %%
mode_embark=titanic_df["Embarked"].mode()[0]
print(mode_embark)
# Out:
# S

# %%
titanic_df["Embarked"].fillna(mode_embark,inplace=True)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_3976\3737946156.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic_df["Embarked"].fillna(mode_embark,inplace=True)

# %% [markdown]
# Verify that there are no more missing values in the 'Embarked' column.

# %%
titanic_df["Embarked"].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# The 'Cabin' column is missing too much data to be useful. We will remove it.

# %%
titanic_df.drop(["Cabin"],axis=1,inplace=True)

# %% [markdown]
# Confirm the 'Cabin' column is no longer present in the DataFrame's columns.

# %%
titanic_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %% [markdown]
# The 'Age' column is currently a float, but it should be an integer. Convert it.

# %%
titanic_df["Age"]=titanic_df.Age.astype("int64")

# %% [markdown]
# The 'Pclass' column is numerical but represents categories. Convert it to a string or category type.

# %%
titanic_df['Pclass']=titanic_df.Pclass.astype("object")

# %% [markdown]
# The 'Survived' column is an integer but represents categories. Convert it to a category type.

# %%
titanic_df.Survived=titanic_df.Survived.astype("object")

# %% [markdown]
# Display the data types of all columns again to confirm your changes.

# %%
titanic_df.dtypes
# Out:
# PassengerId      int64
# Survived        object
# Pclass          object
# Name            object
# Sex             object
# Age              int64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Embarked        object
# dtype: object

# %% [markdown]
# Create a new column 'Sex_numeric' that is 1 for 'female' and 0 for 'male'.

# %%
titanic_df['Sex_numeric']=np.where(titanic_df["Sex"] == "male",0,1)

# %% [markdown]
# Create a copy of the DataFrame for this task called 'titanic_ml'.

# %%
titanic_ml=titanic_df.copy()

# %% [markdown]
# In 'titanic_ml',create new columns for each category in the 'Embarked' column (e.g., 'Embarked_S', 'Embarked_C', 'Embarked_Q') and populate them with 1s and 0s

# %%
titanic_ml['Embarked_S']=np.where(titanic_ml["Embarked"] == 'S',1,0)
titanic_ml['Embarked_C']=np.where(titanic_ml["Embarked"] == 'C',1,0)
titanic_ml['Embarked_Q']=np.where(titanic_ml["Embarked"] == 'Q',1,0)

# %% [markdown]
# Drop the original 'Sex' and 'Embarked' columns from 'titanic_ml'.

# %%
titanic_ml.drop(['Sex','Embarked'],axis=1,inplace=True)

# %% [markdown]
# drop the 'Name', 'Ticket', and 'PassengerId' columns as they are not useful for a model.

# %%
titanic_ml.drop(['Name','PassengerId','Ticket'],axis=1,inplace=True)

# %% [markdown]
# Display the first 5 rows of the 'titanic_ml' DataFrame.

# %%
titanic_ml.head()
# Out:
#   Survived Pclass  Age  SibSp  Parch     Fare  Sex_numeric  Embarked_S  \
# 0        0      3   22      1      0   7.2500            0           1
# 1        1      1   38      1      0  71.2833            1           0
# 2        1      3   26      0      0   7.9250            1           1
# 3        1      1   35      1      0  53.1000            1           1
# 4        0      3   35      0      0   8.0500            0           1
#
#    Embarked_C  Embarked_Q
# 0           0           0
# 1           1           0
# 2           0           0
# 3           0           0
# 4           0           0

# %% [markdown]
# Display the data types for 'titanic_ml' to ensure all are numeric.

# %%
titanic_ml.dtypes
# Out:
# Survived        object
# Pclass          object
# Age              int64
# SibSp            int64
# Parch            int64
# Fare           float64
# Sex_numeric      int64
# Embarked_S       int64
# Embarked_C       int64
# Embarked_Q       int64
# dtype: object

# %% [markdown]
# Keep the original 'titanic_df' for the rest of the analysis.

# %%
display(titanic_df)
# Out:
#      PassengerId Survived Pclass  \
# 0              1        0      3
# 1              2        1      1
# 2              3        1      3
# 3              4        1      1
# 4              5        0      3
# ..           ...      ...    ...
# 886          887        0      2
# 887          888        1      1
# 888          889        0      3
# 889          890        1      1
# 890          891        0      3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# ...

# %% [markdown]
# Create a new column 'FamilySize' which is the sum of 'SibSp' and 'Parch' plus 1.

# %%
titanic_df['FamilySize']=titanic_df['SibSp']+titanic_df['Parch']+1

# %% [markdown]
# Create a new column 'IsAlone' that is 1 if 'FamilySize' is 1, and 0 otherwise.

# %%
titanic_df['IsAlone']=np.where(titanic_df['FamilySize'] == 1,1,0)

# %% [markdown]
# Display the first 5 rows showing 'SibSp', 'Parch', 'FamilySize', and 'IsAlone'.

# %%
titanic_df[['SibSp','Parch','FamilySize','IsAlone']].head()
# Out:
#    SibSp  Parch  FamilySize  IsAlone
# 0      1      0           2        0
# 1      1      0           2        0
# 2      0      0           1        1
# 3      1      0           2        0
# 4      0      0           1        1

# %% [markdown]
# Create a new column 'Title' by extracting the title from the 'Name' column. For example, in 'Braund, Mr. Owen Harris', the title is 'Mr.'

# %%
def func(row):
        if 'Mr' in row.Name:
            return 'Mr'
        elif 'Mrs' in row.Name:
            return 'Mrs'
        elif 'Miss' in row.Name:
            return 'Miss'
        else:
             return 'Other'
titanic_df['Title']=titanic_df.apply(func,axis=1)

# %% [markdown]
# Display the unique titles and their counts.

# %%
titanic_df.Title.value_counts()
# Out:
# Title
# Mr       647
# Miss     180
# Other     64
# Name: count, dtype: int64

# %% [markdown]
# Display the new counts of the simplified titles.

# %%
titanic_df['Title'].value_counts()
# Out:
# Title
# Mr       647
# Miss     180
# Other     64
# Name: count, dtype: int64

# %% [markdown]
# Create a new column 'AgeGroup' that categorizes passengers into groups: 'Child' (0-12), 'Teen' (13-19), 'Adult' (20-59), 'Senior' (60+).

# %%
def ageclass(row):
    if row.Age <=12:
        return 'Child'
    elif row.Age <=19:
        return 'Teen'
    elif row.Age <= 59:
        return 'Adult'
    else:
        return 'Senior'
titanic_df['AgeGroup']=titanic_df.apply(ageclass,axis=1)

# %% [markdown]
# Display the counts for each 'AgeGroup'.

# %%
titanic_df.AgeGroup.value_counts()
# Out:
# AgeGroup
# Adult     701
# Teen       95
# Child      69
# Senior     26
# Name: count, dtype: int64

# %% [markdown]
# Display the first 10 rows with the new 'Title' and 'AgeGroup' columns.

# %%
display(titanic_df[['Title','AgeGroup']].head(10))
# Out:
#    Title AgeGroup
# 0     Mr    Adult
# 1     Mr    Adult
# 2   Miss    Adult
# 3     Mr    Adult
# 4     Mr    Adult
# 5     Mr    Adult
# 6     Mr    Adult
# 7  Other    Child
# 8     Mr    Adult
# 9     Mr     Teen

# %% [markdown]
# Create a 'Fare_Per_Person' column by dividing 'Fare' by 'FamilySize'.

# %%
titanic_df['Fare_Per_Person']=titanic_df['Fare']/titanic_df['FamilySize']

# %% [markdown]
# Display the 'Fare', 'FamilySize', and 'Fare_Per_Person' for the first 5 rows.

# %%
display(titanic_df[['Fare','FamilySize','Fare_Per_Person']])
# Out:
#         Fare  FamilySize  Fare_Per_Person
# 0     7.2500           2          3.62500
# 1    71.2833           2         35.64165
# 2     7.9250           1          7.92500
# 3    53.1000           2         26.55000
# 4     8.0500           1          8.05000
# ..       ...         ...              ...
# 886  13.0000           1         13.00000
# 887  30.0000           1         30.00000
# 888  23.4500           4          5.86250
# 889  30.0000           1         30.00000
# 890   7.7500           1          7.75000
#
# [891 rows x 3 columns]

# %% [markdown]
# What is the average fare per person for those who survived vs. those who did not?

# %%
avg_fare_alive_vs_dead=titanic_df.groupby(["Survived"]).Fare.mean()
print(avg_fare_alive_vs_dead)
# Out:
# Survived
# 0    22.117887
# 1    48.395408
# Name: Fare, dtype: float64

# %% [markdown]
# What is the average family size for those who survived vs. those who did not?

# %%
avg_fam_size=titanic_df.groupby(["Survived"]).FamilySize.mean()
print(avg_fam_size)
# Out:
# Survived
# 0    1.883424
# 1    1.938596
# Name: FamilySize, dtype: float64

# %% [markdown]
# What is the survival rate for people who were alone vs. not alone?

# %%
survival_rate=titanic_df.groupby(['IsAlone']).Survived.mean()
print(survival_rate)
# Out:
# IsAlone
# 0     0.50565
# 1    0.303538
# Name: Survived, dtype: object

# %% [markdown]
# Find the passenger with the highest fare per person.

# %%
highest=titanic_df.Fare_Per_Person.max()
print(titanic_df.loc[titanic_df.Fare_Per_Person==highest,['Name','PassengerId','Fare_Per_Person']])
# Out:
#                        Name  PassengerId  Fare_Per_Person
# 258        Ward, Miss. Anna          259         512.3292
# 737  Lesurer, Mr. Gustave J          738         512.3292

# %% [markdown]
# Find the family with the largest family size.

# %%
largest_fam=titanic_df.FamilySize.max()
print(titanic_df.loc[titanic_df['FamilySize'] == largest_fam,['Name',"FamilySize"]])
# Out:
#                                   Name  FamilySize
# 159         Sage, Master. Thomas Henry          11
# 180       Sage, Miss. Constance Gladys          11
# 201                Sage, Mr. Frederick          11
# 324           Sage, Mr. George John Jr          11
# 792            Sage, Miss. Stella Anna          11
# 846           Sage, Mr. Douglas Bullen          11
# 863  Sage, Miss. Dorothy Edith "Dolly"          11

# %% [markdown]
#  Group the data by 'Title' and find the median age for each title.

# %%
median_age=[]
median_age.append(titanic_df.groupby(['Title']).Age.median())
print(median_age)
# Out:
# [Title
# Miss     24.0
# Mr       28.0
# Other     9.5
# Name: Age, dtype: float64]

# %% [markdown]
#  Group the data by 'Pclass' and 'Sex', and find the survival rate for each group.

# %%
display(titanic_df.groupby(['Pclass','Sex']).Survived.mean())
# Out:
# Pclass  Sex
# 1       female    0.968085
#         male      0.368852
# 2       female    0.921053
#         male      0.157407
# 3       female         0.5
#         male      0.135447
# Name: Survived, dtype: object

# %% [markdown]
# Display the entire DataFrame with all the new engineered features.

# %%
display(titanic_df)
# Out:
#      PassengerId Survived Pclass  \
# 0              1        0      3
# 1              2        1      1
# 2              3        1      3
# 3              4        1      1
# 4              5        0      3
# ..           ...      ...    ...
# 886          887        0      2
# 887          888        1      1
# 888          889        0      3
# 889          890        1      1
# 890          891        0      3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# ...

# %%
male_survival_rate = titanic_df[titanic_df['Sex'] == 'male']['Survived'].mean()
print(f"Survival rate for male passengers: {male_survival_rate:.2%}")
# Out:
# Survival rate for male passengers: 18.89%

# %% [markdown]
# What was the survival rate for each 'Title'?

# %%
print(titanic_df.groupby(["Title"]).Survived.mean())
# Out:
# Title
# Miss          0.7
# Mr       0.284389
# Other         0.5
# Name: Survived, dtype: object

# %% [markdown]
# What was the survival rate for each 'AgeGroup'?

# %%
print(titanic_df.groupby(["AgeGroup"]).Survived.mean())
# Out:
# AgeGroup
# Adult     0.365193
# Child      0.57971
# Senior    0.269231
# Teen      0.410526
# Name: Survived, dtype: object

# %% [markdown]
# Combine 'Pclass' and 'Sex'. What was the survival rate for females in first class?

# %%
female_first_class=titanic_df[(titanic_df["Sex"] =='female') & (titanic_df['Pclass'] ==1)]
print(female_first_class.Survived.mean())
# Out:
# 0.9680851063829787

# %% [markdown]
# What was the survival rate for males in third class?

# %%
male_third_class_rate=titanic_df[(titanic_df["Sex"] == 'male') & (titanic_df["Pclass"] == 3)]['Survived'].mean()
print(male_third_class_rate)
# Out:
# 0.13544668587896252

# %% [markdown]
# What was the survival rate for children in third class?

# %%
child_third_survival_rate=titanic_df[(titanic_df["AgeGroup"] == "Child") & (titanic_df["Pclass"]== 3)]['Survived'].mean()
print(child_third_survival_rate)
# Out:
# 0.4166666666666667

# %% [markdown]
# What was the average fare paid by passengers from each 'Embarked' port?

# %%
print(titanic_df.groupby(['Embarked']).Fare.mean())
# Out:
# Embarked
# C    59.954144
# Q    13.276030
# S    27.243651
# Name: Fare, dtype: float64

# %% [markdown]
# What was the average fare paid by each 'AgeGroup'?

# %%
print(titanic_df.groupby(['AgeGroup']).Fare.mean())
# Out:
# AgeGroup
# Adult     31.882233
# Child     31.536352
# Senior    43.467950
# Teen      31.982414
# Name: Fare, dtype: float64

# %% [markdown]
#  Find the survival rate for passengers who paid less than the median fare.

# %%
median_fare=titanic_df.Fare_Per_Person.median()
less_than_median=titanic_df[titanic_df['Fare_Per_Person'] < median_fare]['Survived'].mean()
print(less_than_median)
# Out:
# 0.2606741573033708

# %% [markdown]
#  Find the survival rate for passengers who paid more than the median fare.

# %%
more_than_median=titanic_df[titanic_df['Fare_Per_Person'] > median_fare]['Survived'].mean()
print(more_than_median)
# Out:
# 0.5078651685393258

# %% [markdown]
# Who had a better survival rate, people traveling alone or people with families?

# %%
print(titanic_df.groupby("IsAlone").Survived.mean())   #people traveling alone has more survival rate
# Out:
# IsAlone
# 0     0.50565
# 1    0.303538
# Name: Survived, dtype: object

# %% [markdown]
# For families of size 2, what was the survival rate?

# %%
fam_of_2=titanic_df[titanic_df['FamilySize']==2]['Survived'].mean()
print(fam_of_2)
# Out:
# 0.5527950310559007

# %% [markdown]
# For families of size 3, what was the survival rate?

# %%
fam_of_3=titanic_df[titanic_df['FamilySize']==3]['Survived'].mean()
print(fam_of_3)
# Out:
# 0.5784313725490197

# %% [markdown]
# For families of size 4, what was the survival rate?

# %%
fam_of_4=titanic_df[titanic_df['FamilySize']==4]['Survived'].mean()
print(fam_of_4)
# Out:
# 0.7241379310344828

# %% [markdown]
# What about for very large families (FamilySize > 4)? What was their survival rate?

# %%
fam_of_more=titanic_df[titanic_df['FamilySize'] > 4]['Survived'].mean()
print(fam_of_more)
# Out:
# 0.16129032258064516

# %% [markdown]
# Group the data by 'Embarked' and 'Pclass'. What was the average fare for a first-class passenger from Cherbourg ('C')?

# %%
print(titanic_df.groupby(['Embarked']).Fare.mean())
# Out:
# Embarked
# C    59.954144
# Q    13.276030
# S    27.243651
# Name: Fare, dtype: float64

# %% [markdown]
# Find the oldest passenger who survived.

# %%
max_age=titanic_df.Age.max()
print(titanic_df.loc[(titanic_df["Survived"] == 1) & (titanic_df["Age"] == max_age),["Name",'PassengerId','Age','Survived']])
# Out:
#                                      Name  PassengerId  Age Survived
# 630  Barkworth, Mr. Algernon Henry Wilson          631   80        1

# %% [markdown]
# Find the youngest passenger who survived.

# %%
min_age = titanic_df.Age.min()
youngest=titanic_df.loc[(titanic_df.Survived == 1) & (titanic_df.Age == min_age),['Name','Age','Survived']]
print(youngest)
# Out:
#                                 Name  Age Survived
# 78     Caldwell, Master. Alden Gates    0        1
# 305   Allison, Master. Hudson Trevor    0        1
# 469    Baclini, Miss. Helene Barbara    0        1
# 644           Baclini, Miss. Eugenie    0        1
# 755        Hamalainen, Master. Viljo    0        1
# 803  Thomas, Master. Assad Alexander    0        1
# 831  Richards, Master. George Sibley    0        1

# %% [markdown]
# Select all the passengers with the title 'Dr.'. What was their survival rate?

# %%
titanic_df["Doctors"]=titanic_df['Name'].str.extract(r"(Dr\.)")
titanic_df.groupby("Doctors").Survived.mean()
# Out:
# Doctors
# Dr.    0.428571
# Name: Survived, dtype: object

# %% [markdown]
# How many children ('Child' AgeGroup) were in first class?

# %%
num_of_child=titanic_df[(titanic_df["AgeGroup"]== 'Child') & (titanic_df["Pclass"]== 1)]['PassengerId'].count()
print(num_of_child)
# Out:
# 4

# %% [markdown]
# What was the survival rate of children in first class?

# %%
survival_rate_of_childs=titanic_df[(titanic_df["AgeGroup"]== 'Child') & (titanic_df["Pclass"]== 1)]['Survived'].mean()
print(survival_rate_of_childs)
# Out:
# 0.75

# %% [markdown]
# Extract the 'Fare_Per_Person' and 'Age' columns into NumPy arrays named 'fare_np' and 'age_np'.

# %%
fare_np=titanic_df.Fare_Per_Person.to_numpy()
age_np=titanic_df.Age.to_numpy()

# %% [markdown]
# For 'fare_np', calculate the mean, median, standard deviation, min, and max.

# %%
print(f"Mean : {fare_np.mean()} \nMedian : {np.median(fare_np)}\nStandard deviaton : {fare_np.std()}\nmin : {fare_np.min()}\nMax : {fare_np.max()}")
# Out:
# Mean : 19.916375111917638
# Median : 8.3
# Standard deviaton : 35.82113871450563
# min : 0.0
# Max : 512.3292

# %% [markdown]
# For 'age_np', calculate the mean, median, standard deviation, min, and max.

# %%
print(f"Mean : {age_np.mean()} \nMedian : {np.median(age_np)}\nStandard deviaton : {age_np.std()}\nmin : {age_np.min()}\nMax : {age_np.max()}")
# Out:
# Mean : 29.34567901234568
# Median : 28.0
# Standard deviaton : 13.020898804757042
# min : 0
# Max : 80

# %% [markdown]
# Using boolean indexing on 'fare_np', count how many passengers paid more than $100 per person.

# %%
people_paid_more=fare_np[fare_np > 100]
print(people_paid_more)
# Out:
# [123.7604  146.5208  512.3292  135.6333  123.7604  110.8833  135.6333
#  134.5     135.6333  227.525   221.7792  106.425   227.525   153.4625
#  256.1646  105.66875 113.7625  151.55    227.525   211.3375  512.3292
#  105.66875]

# %% [markdown]
#  Using boolean indexing on 'age_np', calculate the average age of passengers who were older than 40.

# %%
people_age_more=age_np[age_np > 40]
print(people_age_more)
# Out:
# [54 58 55 66 42 49 65 45 46 59 71 47 70 54 45 47 42 51 55 51 44 45 61 56
#  50 45 44 58 42 45 42 51 59 44 44 54 62 41 50 52 58 41 63 45 65 42 50 43
#  54 61 45 41 45 45 42 45 60 42 46 51 44 42 50 64 45 52 49 65 50 48 47 48
#  56 50 63 58 55 71 54 54 47 44 50 45 50 64 62 48 62 53 54 47 60 52 47 49
#  49 44 42 61 57 80 51 41 48 56 58 50 47 43 70 43 60 60 52 44 49 42 45 42
#  48 52 50 48 70 48 41 51 48 57 54 43 46 49 43 52 62 42 74 44 45 51 41 48
#  42 47 47 56]

# %% [markdown]
#  Create a boolean mask for fares greater than 50.

# %%
mask_fare=fare_np > 50
print(mask_fare)
# Out:
# [False False False False False False  True False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False  True False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False  True False False False False False False False False False False
#   True False  True False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False  True False False False False False False False  True False
#  False False False False False False False False False False False False
#  False False False False False False False  True False False False False
#  False False False False False False False False False False False False
# ...

# %% [markdown]
# Create a new array 'adjusted_fare_np' that is a copy of 'fare_np'.

# %%
adjusted_fare_np=fare_np.copy()
print(adjusted_fare_np)
# Out:
# [  3.625       35.64165      7.925       26.55         8.05
#    8.4583      51.8625       4.215        3.7111      15.0354
#    5.56666667  26.55         8.05         4.46785714   7.8542
#   16.           4.85416667  13.           9.           7.225
#   26.          13.           8.0292      35.5          4.215
#    4.48392857   7.225       43.83333333   7.8792       7.8958
#   27.7208      73.2604       7.75        10.5         41.0854
#   26.           7.2292       8.05         6.           5.62085
#    4.7375      10.5          7.8958      10.3948       7.8792
#    8.05         7.75         7.75         7.2264       8.9
#    6.61458333   7.8         38.3646      13.          30.9896
#   35.5         10.5          7.2292       6.9375       5.8625
#    7.2292      80.          41.7375       4.65        27.7208
#    5.08193333  10.5          8.1583       1.13214286   2.8875
#   10.5          5.8625      73.5          7.2271      56.4958
# ...

# %% [markdown]
#  Use the mask and broadcasting to multiply the fares over 50 in 'adjusted_fare_np' by 1.10.

# %%
adjusted_fare_np[mask_fare]=adjusted_fare_np[mask_fare] * 1.10
print(adjusted_fare_np)
# Out:
# [  3.625       35.64165      7.925       26.55         8.05
#    8.4583      57.04875      4.215        3.7111      15.0354
#    5.56666667  26.55         8.05         4.46785714   7.8542
#   16.           4.85416667  13.           9.           7.225
#   26.          13.           8.0292      35.5          4.215
#    4.48392857   7.225       43.83333333   7.8792       7.8958
#   27.7208      80.58644      7.75        10.5         41.0854
#   26.           7.2292       8.05         6.           5.62085
#    4.7375      10.5          7.8958      10.3948       7.8792
#    8.05         7.75         7.75         7.2264       8.9
#    6.61458333   7.8         38.3646      13.          30.9896
#   35.5         10.5          7.2292       6.9375       5.8625
#    7.2292      88.          41.7375       4.65        27.7208
#    5.08193333  10.5          8.1583       1.13214286   2.8875
#   10.5          5.8625      80.85         7.2271      62.14538
# ...

# %% [markdown]
# Calculate the total increase in revenue from this new tax.

# %%
total_increase=adjusted_fare_np.sum()-fare_np.sum()
print(total_increase)
# Out:
# 712.1619133333334

# %% [markdown]
# Add the 'adjusted_fare_np' array back to the original 'titanic_df' as a new column called 'AdjustedFare'.

# %%
titanic_df["AdjustedFare"]=adjusted_fare_np

# %% [markdown]
# Select the fares of all male passengers who were in third class. Convert this to a NumPy array.

# %%
np_male_3_fare=titanic_df.loc[(titanic_df["Sex"]== 'male') & (titanic_df["Pclass"] == 3),["Fare"]].to_numpy()

# %% [markdown]
# Calculate the mean fare for this specific group.

# %%
print(np_male_3_fare.mean())
# Out:
# 12.661632564841499

# %% [markdown]
# Select the ages of all female passengers who were in first class and survived. Convert this to a NumPy array.

# %%
np_female_1_age=titanic_df.loc[(titanic_df["Sex"] == 'female') & (titanic_df["Pclass"] == 1),['Age']].to_numpy()
print(np_female_1_age)
# Out:
# [[38]
#  [35]
#  [58]
#  [28]
#  [49]
#  [38]
#  [23]
#  [19]
#  [22]
#  [28]
#  [50]
#  [44]
#  [58]
#  [31]
#  [32]
#  [35]
#  [28]
#  [30]
#  [35]
#  [58]
#  [35]
#  [63]
#  [26]
#  [19]
#  [ 2]
#  [50]
#  [28]
#  [17]
#  [30]
#  [24]
#  [18]
#  [31]
#  [40]
#  [36]
#  [16]
#  [28]
#  [41]
#  [24]
#  [22]
#  [60]
#  [24]
#  [28]
#  [42]
#  [35]
#  [23]
#  [33]
#  [14]
#  [28]
#  [35]
#  [54]
#  [25]
#  [16]
#  [54]
#  [30]
#  [44]
#  [30]
#  [22]
#  [36]
#  [48]
#  [39]
#  [53]
#  [39]
#  [39]
#  [18]
#  [52]
#  [40]
#  [21]
#  [24]
#  [28]
#  [15]
#  [18]
#  [22]
#  [24]
#  [38]
#  [29]
#  [21]
#  [33]
#  [36]
#  [51]
#  [43]
#  [17]
#  [49]
#  [33]
#  [52]
#  [62]
#  [39]
#  [30]
#  [28]
#  [16]
#  [45]
#  [48]
#  [47]
#  [56]
#  [19]]

# %% [markdown]
# Calculate the median age for this specific group.

# %%
print(np.median(np_female_1_age))
# Out:
# 32.5

# %% [markdown]
# Calculate the correlation coefficient between 'FamilySize' and 'Fare_Per_Person'. What does this tell you?

# %%
correlation=np.corrcoef(titanic_df.FamilySize,titanic_df.Fare_Per_Person)[0,1]
print(correlation)     #Negative Strong linear relationship
# Out:
# -0.09917254586771769

# %% [markdown]
# Standardize the 'Age' column: subtract the mean and divide by the standard deviation. Store this in a new NumPy array 'age_standardized'.

# %%
mean_age=titanic_df.Age.mean()
std_age=titanic_df.Age.std()
age_standardized=((titanic_df.Age -mean_age) / std_age).to_numpy()
print(age_standardized)
# Out:
# [-0.56382864  0.66427543 -0.25680263  0.43400591  0.43400591 -0.10328962
#   1.8923795  -2.09895873 -0.18004612 -1.17788068 -1.94544572  2.19940551
#  -0.71734165  0.74103193 -1.17788068  1.969136   -2.09895873 -0.10328962
#   0.1269799  -0.10328962  0.43400591  0.35724941 -1.10112417 -0.10328962
#  -1.6384197   0.66427543 -0.10328962 -0.79409816 -0.10328962 -0.10328962
#   0.81778843 -0.10328962 -0.10328962  2.81345755 -0.10328962  0.97130144
#  -0.10328962 -0.64058515 -0.87085466 -1.17788068  0.81778843 -0.18004612
#  -0.10328962 -2.02220222 -0.79409816 -0.10328962 -0.10328962 -0.10328962
#  -0.10328962 -0.87085466 -1.71517621 -0.64058515  1.50859697 -0.02653311
#   2.73670104 -0.10328962 -0.64058515 -0.10328962 -1.86868922 -1.40815019
#  -0.56382864  0.66427543  1.20157096 -1.94544572 -0.10328962 -0.10328962
#  -0.02653311 -0.79409816 -0.94761116 -0.25680263  0.2037364  -1.02436767
#  -0.64058515 -0.25680263  0.2037364  -0.33355913 -0.10328962 -0.10328962
# ...

# %% [markdown]
# Standardize the 'Fare_Per_Person' column. Store this in a new NumPy array 'fare_standardized'.

# %%
mean_fare_per=titanic_df.Fare_Per_Person.mean()
std_fare_per=titanic_df.Fare_Per_Person.std()
fare_standardized=((titanic_df.Fare_Per_Person - mean_fare_per) / std_fare_per).to_numpy()
print(fare_standardized)
# Out:
# [-4.54542512e-01  4.38747859e-01 -3.34569042e-01  1.85083487e-01
#  -3.31081441e-01 -3.19689541e-01  8.91322663e-01 -4.38081036e-01
#  -4.52140252e-01 -1.36183144e-01 -4.00368445e-01  1.85083487e-01
#  -3.31081441e-01 -4.31026117e-01 -3.36544419e-01 -1.09270026e-01
#  -4.20247770e-01 -1.92972447e-01 -3.04575674e-01 -3.54099607e-01
#   1.69738043e-01 -1.92972447e-01 -3.31661778e-01  4.34795709e-01
#  -4.38081036e-01 -4.30577711e-01 -3.54099607e-01  6.67302434e-01
#  -3.35846899e-01 -3.35383745e-01  2.17749752e-01  1.48834134e+00
#  -3.39451683e-01 -2.62724464e-01  5.90632876e-01  1.69738043e-01
#  -3.53982423e-01 -3.31081441e-01 -3.88278095e-01 -3.98856686e-01
#  -4.23502864e-01 -2.62724464e-01 -3.35383745e-01 -2.65659629e-01
#  -3.35846899e-01 -3.31081441e-01 -3.39451683e-01 -3.39451683e-01
#  -3.54060546e-01 -3.07365755e-01 -3.71130724e-01 -3.38056643e-01
#   5.14720361e-01 -1.92972447e-01  3.08951910e-01  4.34795709e-01
# ...

# %% [markdown]
# Find the passenger who is the biggest outlier in terms of standardized age (i.e., has the largest absolute standardized age).

# %%
abs_age= np.abs(age_standardized)
id_age=np.argmax(abs_age)
print(titanic_df.loc[id_age,['PassengerId','Name','Age']])
# Out:
# PassengerId                                     631
# Name           Barkworth, Mr. Algernon Henry Wilson
# Age                                              80
# Name: 630, dtype: object

# %% [markdown]
# Find the passenger who is the biggest outlier in terms of standardized fare.

# %%
abs_fare=np.abs(fare_standardized)
id_age=np.argmax(abs_fare)
print(titanic_df.iloc[id_age])
# Out:
# PassengerId                     259
# Survived                          1
# Pclass                            1
# Name               Ward, Miss. Anna
# Sex                          female
# Age                              35
# SibSp                             0
# Parch                             0
# Ticket                     PC 17755
# Fare                       512.3292
# Embarked                          C
# Sex_numeric                       1
# FamilySize                        1
# IsAlone                           1
# Title                          Miss
# AgeGroup                      Adult
# Fare_Per_Person            512.3292
# Doctors                         NaN
# AdjustedFare              563.56212
# Name: 258, dtype: object

# %% [markdown]
# Calculate the survival rate for passengers with a standardized age greater than 1 (i.e., more than one standard deviation older than the mean).

# %%
mask=age_standardized > 1
print(age_standardized[mask].mean())
# Out:
# 1.7846823844540731

# %% [markdown]
# Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
ax=sns.histplot(data=titanic_df,x="Age",kde=True)
for a in ax.containers:
    ax.bar_label(a,fontweight="bold",fontsize=7.5)
plt.title("Distrubution of Ages")
plt.show()

# %%
counts=titanic_df["Survived"].value_counts()
plt.pie(counts,labels=["Died","Survived"],autopct="%1.1f%%")
plt.title("Survived vs Died")
plt.show()

# %%
pclass_counts=titanic_df["Pclass"].value_counts()
bars=plt.bar(["first class","Second class","third class"],height=pclass_counts,width=.5)
for bar in bars:
    height=bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width()/2.5,
        height + 5,
        str(height)
    )
plt.ylabel("Number of Passengers")
plt.title("Number of Passengers in Each Class",fontdict={"fontsize":10})
# Out:
# Text(0.5, 1.0, 'Number of Passengers in Each Class')

# %%
counts_gender=titanic_df["Sex"].value_counts()
plt.subplot(1,2,1)
plt.pie(counts_gender,labels=["Male","Female"],autopct="%1.1f%%")
plt.subplot(1,2,2)
bars=plt.bar(["Male","Female"],height=counts_gender)
for bar in bars:
    height=bar.get_height()
    plt.text(
    bar.get_x() + bar.get_width()/2,
    height + 8,
    str(height),
    fontsize=10
    )
plt.show()

# %% [markdown]
# Relationship between survival and age

# %%
sns.swarmplot(x="Survived",y="Age",data=titanic_df,palette=["red","green"])
plt.xticks([0,1],["Died","Survived"])
plt.show()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_3976\3535508863.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x="Survived",y="Age",data=titanic_df,palette=["red","green"])
# c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 19.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 5.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# Fare price and Survival

# %%
fig = px.bar(
    titanic_df.groupby("Survived", as_index=False)["Fare_Per_Person"].mean(),
    x="Survived",
    y="Fare_Per_Person",
    title="Average Fare Per Person by Survival"
)
fig.show()

# %% [markdown]
# Were younger passengers more likely to survive than older ones?

# %%
fig = px.histogram(
    titanic_df,
    x="Age",
    color="Survived",
    barmode="overlay",
    nbins=30,
    title="Age Distribution of Survivors vs Non-Survivors",
    color_discrete_sequence={1:'green',0:'red'}
)
fig.show()

# %%
titanic_ml.dtypes
# Out:
# Survived        object
# Pclass          object
# Age              int64
# SibSp            int64
# Parch            int64
# Fare           float64
# Sex_numeric      int64
# Embarked_S       int64
# Embarked_C       int64
# Embarked_Q       int64
# dtype: object

# %%
titanic_ml['Family_Size']=titanic_df['FamilySize']

# %%
titanic_ml.drop(columns=['Parch','SibSp'],inplace=True)

# %%
titanic_ml['Survived'] = titanic_ml['Survived'].astype(int)
titanic_ml['Pclass'] = titanic_ml['Pclass'].astype(int)

# %%
titanic_ml.reset_index(drop=True)
# Out:
#      Survived  Pclass  Age     Fare  Sex_numeric  Embarked_S  Embarked_C  \
# 0           0       3   22   7.2500            0           1           0
# 1           1       1   38  71.2833            1           0           1
# 2           1       3   26   7.9250            1           1           0
# 3           1       1   35  53.1000            1           1           0
# 4           0       3   35   8.0500            0           1           0
# ..        ...     ...  ...      ...          ...         ...         ...
# 886         0       2   27  13.0000            0           1           0
# 887         1       1   19  30.0000            1           1           0
# 888         0       3   28  23.4500            1           1           0
# 889         1       1   26  30.0000            0           0           1
# 890         0       3   32   7.7500            0           0           0
#
#      Embarked_Q  Family_Size
# 0             0            2
# 1             0            2
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X = titanic_ml.drop(['Survived'],axis=1)
y= titanic_ml['Survived']

# %%
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=.2,random_state=42,stratify=y)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score,RandomizedSearchCV

# %%
models= {
    'Logistic':LogisticRegression(),
    'DecisionTree':DecisionTreeClassifier(),
    'SVM':SVC(),
    'XGB':XGBClassifier(),
    'Forest':RandomForestClassifier()
}
for name,model in models.items():
    pipe=Pipeline(steps=[
        ('scaler',StandardScaler()),
        ('model',model)
    ])

    scores=cross_val_score(pipe,x_train,y_train,cv=5)
    print(f'{name} accuracy is: {scores.mean()}')
# Out:
# Logistic accuracy is: 0.8006303555599329
# DecisionTree accuracy is: 0.7669654289372598
# SVM accuracy is: 0.8300797793755541
# XGB accuracy is: 0.7880232443612725
# Forest accuracy is: 0.7894907908992416

# %%
from scipy.stats import loguniform
pipe=Pipeline(steps=[
    ('scaler', StandardScaler()),
    ('model', SVC())
])
param_dist={
    'model__C':[0.5, 1, 5, 10],
    'model__kernel':['rbf'],
    'model__gamma':[0.01, 0.05, 0.1, 0.2]
}
rand=RandomizedSearchCV(
    pipe,
    param_dist,
    n_iter=15,
    cv=5,
    random_state=42,
    scoring='accuracy',
    n_jobs=1
    )

rand.fit(x_train,y_train)
print(rand.best_params_)
print('Train score',rand.score(x_train,y_train))
print('Test score',rand.score(x_test,y_test))
# Out:
# {'model__kernel': 'rbf', 'model__gamma': 0.1, 'model__C': 5}
# Train score 0.8441011235955056
# Test score 0.8156424581005587

# %%
import joblib
joblib.dump(rand.best_estimator_,'svm_model.pkl')
# Out:
# ['svm_model.pkl']

# %%
titanic_ml.columns
# Out:
# Index(['Survived', 'Pclass', 'Age', 'Fare', 'Sex_numeric', 'Embarked_S',
#        'Embarked_C', 'Embarked_Q', 'Family_Size'],
#       dtype='object')
